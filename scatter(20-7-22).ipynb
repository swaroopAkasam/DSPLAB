# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([1, 2, 1, 4, 5])
y = np.array([6, 9, 8, 4, 10])
plt.scatter(x, y, color = 'green' )
a = np.array([3, 5, 9, 12])
b = np.array([6, 3, 7, 9])
plt.scatter(a, b, c = 'yellow')

plt.show()

# %%
x = np.array([1, 4, 7, 12])
y = np.array([1, 13, 14, 17])
colors = ["red", "green", "orange", "hotpink"]
plt.scatter(x, y, c = colors)

# %%
data = [10, 20, 30, 40]
plt.boxplot(data)
plt.show()
